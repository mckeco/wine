# %%
import requests as rq
import time
import pandas as pd
from pandas import json_normalize

# %% [markdown]
# These following functions will account for any edge cases, NULL values or Errors that come up from the Vivino API data.

# %%
def try_get_flavor(vintage):
    try:
        if vintage['vintage']['wine']['taste']['flavor'] is not None:
            return vintage['vintage']['wine']['taste']['flavor']
    except (TypeError, KeyError, IndexError):
        return {'group':None
                , 'stats':{'count': None, 'score': None}
                , 'primary_keywords':[{'id': None, 'name': None, 'count': None}, 
                                    {'id': None, 'name': None, 'count': None},
                                    {'id': None, 'name': None, 'count': None},
                                    {'id': None, 'name': None, 'count': None},
                                    {'id': None, 'name': None, 'count': None}]
                , 'secondary_keywords':None}

# %%
def try_get_grape(vintage):
    try:
        if vintage['vintage']['wine']['style']['varietal_name'] is not None:
            return vintage['vintage']['wine']['style']['varietal_name']
    except (TypeError, KeyError, IndexError):
        return None

# %%
def try_get_food(vintage):
    try:
        if vintage['vintage']['wine']['style']['food'] is not None:
            return vintage['vintage']['wine']['style']['food']
    except (TypeError, KeyError, IndexError):
        return [{'id':None, 'name':None, 'background_image':None, 'seo_name':None}]

# %%
def no_index(row,column):
    l = flavor_df['flavor'][row]
    if type(l) == float or column>len(l):
        return None
    else:
        return flavor_df['flavor'][row][column-1]['group']

# %%
def no_index_score(row,column):
    l = flavor_df['flavor'][row]
    if type(l) == float or column>len(l):
        return None
    else:
        return flavor_df['flavor'][row][column-1]['stats']['count']

# %% [markdown]
# Below is the primary script designed to extract data from Vivino. The resulting list has been curated to align with user preferences. Due to the absence of a designated termination signal for the data extraction process from Vivino, the maximum number of pages retrievable through the API had to be manually determined. Presently, the API permits extraction from 81 pages, with each page containing 25 vintages, resulting in a total allowance of 2025 wines retrievable at once.

# %%
vivino_url = f'https://www.vivino.com/api/explore/explore'
headers={"User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:66.0) Gecko/20100101 Firefox/66.0"}
total = []

for i in range(81):

    request = rq.get(vivino_url,
                    params={
            # "country_code": "US",
            # "country_codes[]":"pt",
            "region_ids[]": '25',
            "currency_code":"USD",
            # "grape_filter":"varietal",
            "min_rating":"2",
            # "order_by":"price",
            # "order":"asc",
            # 'year_range_max':'2011',
            # 'year_range_min':'2010',
            "page": i,
            "price_range_max":"50",
            "price_range_min":"0",
            # "wine_type_ids[]":"1"
                    }, headers = headers).json()['explore_vintage']['matches']

    results = [ (
        i['vintage']['id'],  ## ID number
        i["vintage"]["year"],  ##year made
        i["vintage"]["wine"]["name"],  ##wine name
        try_get_grape(i),
        i['vintage']['wine']['winery']['name'],   ##winery name
        i['vintage']['wine']['winery']['id'], ## winery id
        i["vintage"]["statistics"]["wine_ratings_average"], ##average rating
        i["vintage"]["statistics"]["ratings_count"],##number of ratings
        i["vintage"]['wine']['region']['name'],  ##region name
        i["vintage"]['wine']['region']['id'],  ## region id
        i["vintage"]['wine']['region']['country']['name'], ##Country name
        i['price']['amount'], ## price in USD
        i['vintage']['wine']['taste']['structure'], ## taste structure
        try_get_flavor(i),
        try_get_food(i)
        )
        for i in request]
    
    total.extend(results)
wines = pd.DataFrame(total, columns = ['wine_id', 'year', 'wine','grape_variety', 'winery_name', 'winery_id', 'avg_rating', \
                                       'ratings_count', 'region_name', 'region_id', 'country_name', 'price', 'taste', 'flavor', 'food_list'])

# %% [markdown]
# In order to conduct a thorough exploration of the API, individual vintages are accompanied by distinct flavor profiles. The following code effectively segregates these profiles and organizes them into a standalone DataFrame. Furthermore, to facilitate seamless integration of this DataFrame with others for subsequent analysis or visualization purposes, the wine_id has been reintroduced.

# %%
flavor_df = pd.DataFrame(data=wines['flavor'])
column=0
row=0
for j in range(1,6):
    flavor_df[f'flavor_{j}'] = ""
    flavor_df[f'flavor_{j}_score'] = ""
    
    for i in range(len(wines)):
        flavor_df.at[i, f'flavor_{j}']=no_index(i,j)
        flavor_df.at[i, f'flavor_{j}_score'] = no_index_score(i,j)
flavor_df.insert(0, 'wine_id', wines['wine_id'])
flavor_df.insert(1, 'year', wines['year'])
flavor_df.drop(['flavor'],axis=1, inplace=True)
flavor_df
# Out:
#         wine_id  year      flavor_1 flavor_1_score     flavor_2  \
# 0     175109872  2021     red_fruit              7          oak
# 1       8824369  2014   black_fruit             60          oak
# 2     174194548  2020          None           None         None
# 3     170805604  2021           oak            279  black_fruit
# 4     167920507  2021           oak            490  black_fruit
# ...         ...   ...           ...            ...          ...
# 2020  145108154  2016  citrus_fruit            325   tree_fruit
# 2021    9930656  2013           oak             92    red_fruit
# 2022    4224049  2012  citrus_fruit            640   tree_fruit
# 2023  150349801  2017     red_fruit            215          oak
# 2024  156286590  2018     red_fruit            481          oak
#
#      flavor_2_score        flavor_3 flavor_3_score   flavor_4 flavor_4_score  \
# 0                 7           earth              6    non_oak              6
# 1                53         non_oak             41  red_fruit             32
# 2              None            None           None       None           None
# 3               202       red_fruit            189    non_oak            180
# 4               391         non_oak            319      earth            280
# ...             ...             ...            ...        ...            ...
# 2020            198  tropical_fruit            102      earth             75
# 2021             76     black_fruit             64     spices             61
# 2022            499           earth            317    vegetal            154
# 2023            159           earth            107    non_oak            103
# 2024            370     black_fruit            278    non_oak            207
#
#          flavor_5 flavor_5_score
# 0          spices              5
# 1           earth             30
# 2            None           None
# 3          spices            150
# 4          spices            256
# ...           ...            ...
# 2020      vegetal             67
# 2021      non_oak             53
# 2022     microbio            101
# 2023  black_fruit             66
# 2024        earth            185
#
# [2025 rows x 12 columns]

# %% [markdown]
# We continue the process of creating DataFrames for flavors such as tannin, sweetness and intensity:

# %%
taste_test = json_normalize(wines['taste'])
taste_test.insert(0, 'wine_id', wines['wine_id'])
taste_test.insert(1, 'year', wines['year'])
taste_test.drop(columns=['calculated_structure_count'], inplace=True)
taste_test
# Out:
#         wine_id  year   acidity  fizziness  intensity  sweetness    tannin  \
# 0     175109872  2021  3.136872        NaN   4.951815   1.362780  3.069652
# 1       8824369  2014  3.765815        NaN   4.635574   1.690137  3.382170
# 2     174194548  2020  3.379310        NaN   4.689655   1.893793  4.000000
# 3     170805604  2021  3.404283        NaN   4.807787   1.581869  3.333713
# 4     167920507  2021  3.255934        NaN   4.612567   1.790511  3.267794
# ...         ...   ...       ...        ...        ...        ...       ...
# 2020  145108154  2016  4.069370        NaN   2.967922   1.301144       NaN
# 2021    9930656  2013  2.026529        NaN   4.651704   2.414917  2.627097
# 2022    4224049  2012  4.015811        NaN   2.937798   1.255500       NaN
# 2023  150349801  2017  3.499718        NaN   2.950133   1.490268  2.137976
# 2024  156286590  2018  3.393241        NaN   3.068016   1.542789  2.070833
#
#       user_structure_count
# 0                     10.0
# 1                     26.0
# 2                      0.0
# 3                    367.0
# 4                    567.0
# ...                    ...
# 2020                  67.0
# 2021                  30.0
# 2022                 199.0
# 2023                 153.0
# 2024                 273.0
#
# [2025 rows x 8 columns]

# %% [markdown]
# Now that we have created all of our extra DataFrames, to consolidate and clean up our initial data, we will drop the taste, flavor and food_list from the original data before we create our CSVs.

# %%
wines.drop(['taste','flavor','food_list'],axis=1, inplace=True)
wines
# Out:
#         wine_id  year                               wine       grape_variety  \
# 0     175109872  2021      M By Merus Cabernet Sauvignon  Cabernet Sauvignon
# 1       8824369  2014                      Perry's Blend      Bordeaux Blend
# 2     174194548  2020  Edict Napa Valley Proprietary Red      Bordeaux Blend
# 3     170805604  2021                 Cabernet Sauvignon  Cabernet Sauvignon
# 4     167920507  2021                 Cabernet Sauvignon  Cabernet Sauvignon
# ...         ...   ...                                ...                 ...
# 2020  145108154  2016       Miller Ranch Sauvignon Blanc     Sauvignon Blanc
# 2021    9930656  2013       Ink Grade Vineyard Zinfandel           Zinfandel
# 2022    4224049  2012                    Sauvignon Blanc     Sauvignon Blanc
# 2023  150349801  2017                         Pinot Noir          Pinot Noir
# 2024  156286590  2018                Carneros Pinot Noir          Pinot Noir
#
#               winery_name  winery_id  avg_rating  ratings_count  \
# 0                   Merus       1198         4.5              5
# 1                  Juslyn        406         4.3             38
# 2                   Edict      46553         4.5              9
# 3             Bella Union     115511         4.4             12
# 4            The Prisoner      89393         4.4           1205
# ...                   ...        ...         ...            ...
# 2020  Silverado Vineyards       1205         3.8            400
# 2021         Heitz Cellar      11538         3.8            392
# 2022               Emmolo       5528         3.9            391
# 2023               Artesa       1534         3.9            382
# 2024               Acacia        832         3.8            370
#
#                    region_name  region_id   country_name      price
# 0                  Napa Valley         25  United States  39.999167
# 1     Spring Mountain District         73  United States  44.990000
# 2                  Napa Valley         25  United States  28.990000
# 3                  Napa Valley         25  United States  49.640000
# 4                  Napa Valley         25  United States  42.440000
# ...                        ...        ...            ...        ...
# 2020               Napa Valley         25  United States  12.650000
# 2021               Napa Valley         25  United States  28.920000
# 2022               Napa Valley         25  United States  20.990000
# 2023              Los Carneros         96  United States  18.990000
# 2024              Los Carneros         96  United States  20.990000
#
# [2025 rows x 12 columns]

# %%
## READY FOR EXECUTION
## Back uppppp
row=0
flavor_df = pd.DataFrame(data=wines['flavor'].tolist())
## Defining the columns
flavor_df['group_stat']=''
flavor_df['kw1'] = ""
flavor_df['kw1_score'] = ""
flavor_df['kw2'] = ""
flavor_df['kw2_score'] = ""
flavor_df['kw3'] = ""
flavor_df['kw3_score'] = ""
flavor_df['kw4'] = ""
flavor_df['kw4_score'] = ""
flavor_df['kw5'] = ""
flavor_df['kw5_score'] = ""

for i in range(len(wines)):
    row+=1
    try:
        
        flavor_df['group_stat'][i] = flavor_df['stats'][i]['score']
        flavor_df['kw1'][i] = no_float(i,j)
        flavor_df['kw1_score'][i] = flavor_df['primary_keywords'][i][0]['count']
        flavor_df['kw2'][i] = flavor_df['primary_keywords'][i][1]['name']
        flavor_df['kw2_score'][i] = flavor_df['primary_keywords'][i][1]['count']
        flavor_df['kw3'][i] = flavor_df['primary_keywords'][i][2]['name']
        flavor_df['kw3_score'][i] = flavor_df['primary_keywords'][i][2]['count']
        flavor_df['kw4'][i] = flavor_df['primary_keywords'][i][3]['name']
        flavor_df['kw4_score'][i] = flavor_df['primary_keywords'][i][3]['count']
        flavor_df['kw5'][i] = flavor_df['primary_keywords'][i][4]['name']
        flavor_df['kw5_score'][i] = flavor_df['primary_keywords'][i][4]['count']
    except IndexError:
        flavor_df['group_stat'][i]=None
        flavor_df['kw1'][i]=None
        flavor_df['kw1_score'][i]=None
        flavor_df['kw2'][i]=None
        flavor_df['kw2_score'][i]=None
        flavor_df['kw3'][i]=None
        flavor_df['kw3_score'][i]=None
        flavor_df['kw4'][i]=None
        flavor_df['kw4_score'][i]=None
        flavor_df['kw5'][i]=None
        flavor_df['kw5_score'][i]=None
        
flavor_df.insert(0, 'wine_id', wines['wine_id'])
flavor_df.drop(['stats','primary_keywords','secondary_keywords'],axis=1, inplace=True)
flavor_df
# Out:
#       wine_id         group group_stat   kw1 kw1_score         kw2 kw2_score  \
# 0   173744538     red_fruit      14974  None        62  strawberry        29
# 1   164415516           oak      11480  None        67     vanilla        23
# 2   168607052   black_fruit       6666  None        18  blackberry        17
# 3   162923665           oak      19664  None        91     vanilla        45
# 4   149904981           oak       7499  None        25     vanilla        17
# 5     3506246     red_fruit       6518  None        23   raspberry        12
# 6     1564027    tree_fruit      10000  None        42        pear        24
# 7     2347586     red_fruit       5746  None        19      cherry        19
# 8    11517987     red_fruit       5746  None        19   raspberry        19
# 9   172361342  citrus_fruit       9100  None        42  grapefruit        16
# 10  161764799           oak       7299  None        38     vanilla        16
# 11  156230514           oak      89661  None       378     vanilla       179
# 12  170709754           oak       8500  None        47      butter        39
# 13  160633116           oak       8500  None        47      butter        39
# 14  167494851  citrus_fruit      98100  None       403  grapefruit       208
# 15  163123799  citrus_fruit      98100  None       403  grapefruit       208
# 16  163389400           oak      28385  None       138     vanilla        51
# 17  170336820           oak       5575  None        27      butter        17
# 18   86469289           oak      51293  None       174     vanilla       123
# 19  159504299           oak      76682  None       348      butter       331
# 20  162959873  citrus_fruit      52750  None       226       lemon       119
# 21  156263313           oak      43634  None       150     vanilla       105
# 22  168808579           oak       5548  None        29      butter        25
# 23  157166012           oak       9545  None        43     vanilla        25
# 24  174824712     red_fruit       5213  None        20      cherry         9
#
#             kw3 kw3_score           kw4 kw4_score              kw5 kw5_score
# 0     raspberry        22     red fruit        15       red cherry         8
# 1        butter        19       coconut         4          caramel         3
# 2    dark fruit        13          plum         9  ripe blackberry         3
# 3     chocolate        31       tobacco        12             cola         7
# 4       tobacco        15     chocolate         8   dark chocolate         5
# 5     red fruit        10    strawberry         9        cranberry         4
# 6   green apple        21    asian pear         6      baked apple         2
# 7    strawberry         9     red fruit         3  ripe strawberry         2
# 8    strawberry         9     red fruit         3  ripe strawberry         2
# 9         lemon        12    lemon zest         6             lime         4
# 10    chocolate         5       tobacco         4            mocha         2
# 11    chocolate       108       tobacco        67            cedar        25
# 12      vanilla         6     pie crust         1            cedar         1
# 13      vanilla         6         cedar         1        pie crust         1
# 14        lemon       187          lime        99        tangerine        21
# 15        lemon       187          lime        99        tangerine        21
# 16    chocolate        36       tobacco        14            cedar        13
# 17      vanilla        13     chocolate         3     butterscotch         1
# 18    chocolate        75       tobacco        38            cedar        28
# 19      vanilla       159       caramel        17     butterscotch        14
# 20   grapefruit       103          lime        32       lemon zest        10
# 21    chocolate        73       tobacco        34            cedar        13
# 22      vanilla         8  butterscotch         1            cedar         1
# 23      tobacco        18     chocolate         5     baking spice         3
# 24   watermelon         9     raspberry         4     cotton candy         3

# %% [markdown]
# Finally to turn each DataFrame into a CSV that will assist in the next stages of analysis:

# %%
flavor_df.to_csv('flavor.csv', index=False)
taste_test.to_csv('taste.csv', index=False)
wines.to_csv('wines.csv', index=False)
